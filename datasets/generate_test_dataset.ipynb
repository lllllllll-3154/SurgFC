# %%
import numpy as np
import json
import os

# %%
tool_detect =[
    "Can you detect the surgical instrument in the image?",
    "Identify the surgical tools shown in this picture.",
    "What surgical instruments can you see in this image?",
    "Are there any surgical tools in this photo?",
    "Please list the surgical instruments visible in this image.",
    "Can you point out the surgical instruments in this picture?",
    "Highlight the surgical tools in the image.",
    "Which surgical instruments are present in this photo?",
    "Detect and list all surgical tools in this image.",
    "Can you identify any surgical instruments in this picture?",
    "Show me the surgical tools in this image.",
    "Find the surgical instruments in the photo.",
    "Are there surgical tools in this image? If yes, identify them.",
    "What type of surgical instruments are in the image?",
    "Please confirm if this image contains surgical tools.",
    "Identify and describe the surgical instruments in this photo.",
    "Can you spot any surgical tools in this image?",
    "Name the surgical instruments present in this picture.",
    "List all the surgical tools you can detect in this image.",
    "Are there any tools used in surgery in this picture?",
    "Detect the presence of surgical instruments in the image.",
    "Which tools used in surgeries are visible in this photo?",
    "Can you see any instruments typically used in surgery in this image?",
    "Point out and name the surgical instruments in this picture.",
    "Identify any surgical tools you can find in this image.",
    "What surgical tools are featured in this photo?",
    "Can you list the types of surgical instruments in this image?",
    "Highlight all the surgical instruments in this picture.",
    "Are there any identifiable surgical tools in this image?",
    "Name each surgical instrument visible in the photo.",
    "Please identify the surgical tools in this image.",
    "Show the location of surgical instruments in this picture.",
    "Can you detect any specific surgical tools in this photo?",
    "Identify the type of each surgical instrument in the image.",
    "Please list any surgical tools seen in this picture.",
    "Are surgical instruments visible in this image? Please identify them.",
    "What are the surgical tools present in this photo?",
    "Can you highlight the surgical instruments in this image?",
    "Detect any surgical tools in this picture and list them.",
    "What instruments used in surgery can you see in this image?",
    "Describe the surgical tools visible in this photo.",
    "Can you find and name the surgical instruments in this image?",
    "List the surgical tools detected in this picture.",
    "Are there tools in this image used for surgical purposes?",
    "Identify all surgical instruments in this photo.",
    "Can you point to the surgical tools in this image?",
    "What surgical instruments are shown here?",
    "List and describe the surgical tools in this picture.",
    "Are there identifiable surgical instruments in this image?",
    "Name any surgical tools present in this photo.",
    "Can you identify the instruments used in surgeries in this image?",
    "Highlight the location of any surgical tools in this picture.",
    "What are the visible surgical instruments in this image?",
    "Please find all surgical tools in the photo.",
    "Can you point out the surgical instruments in this image?",
    "Identify the surgical tools in this picture.",
    "List the types of surgical instruments in this photo.",
    "Are there any surgical tools depicted in this image?",
    "What surgical instruments can you identify in this picture?",
    "Name and describe the surgical tools in this image.",
    "Can you see any surgical instruments in this photo?",
    "Point out any surgical tools in this image.",
    "Identify each surgical tool visible in the picture.",
    "Are surgical tools included in the contents of this image?",
    "What surgical tools are in this photo?",
    "Can you list every surgical instrument in this image?",
    "Identify surgical tools seen in this picture.",
    "Describe any surgical instruments in this image.",
    "Are there surgical instruments in this picture? Identify them.",
    "What kind of surgical tools are visible in this photo?",
    "List any surgical instruments found in this image.",
    "Can you detect the surgical instruments in this picture?",
    "Show all surgical tools in this photo.",
    "Identify and list the surgical tools in this image.",
    "Are there tools for surgery in this picture?",
    "Point out the surgical instruments in this image.",
    "What types of surgical instruments are in this photo?",
    "Detect and identify the surgical tools in this image.",
    "Name the surgical instruments shown in this picture.",
    "Can you describe the surgical tools in this photo?",
    "Identify the surgical instruments visible in this image.",
    "Are any surgical tools present in this picture?",
    "List the surgical instruments in this photo.",
    "What surgical tools can you detect in this image?",
    "Point to the surgical instruments in this picture.",
    "Describe the surgical instruments in this image.",
    "Are there any surgical tools in this picture?",
    "Name and list all surgical tools in this image.",
    "Identify the surgical instruments in this photo.",
    "Highlight the surgical tools visible in this picture."
]

# %%
tool_seg = [
    "Can you segment the surgical instrument in the image?",
    "Please identify and segment the surgical tools shown in the picture.",
    "Could you highlight all the surgical instruments in this image?",
    "Segment the surgical tools in the image provided.",
    "Identify and create segments for each surgical tool visible in the image.",
    "Please outline all surgical instruments in the attached image.",
    "Can you isolate and segment the surgical tools in this image?",
    "Detect and segment each surgical instrument in the photo.",
    "Can you provide segmentation for the surgical instruments shown here?",
    "Mark the boundaries of surgical tools in the image.",
    "Locate and segment all surgical instruments in the given image.",
    "Could you delineate the surgical tools in the image?",
    "Please segment the image by identifying the surgical tools.",
    "Highlight and segment all the surgical tools in this picture.",
    "Can you extract the surgical instruments from the image by segmenting them?",
    "Outline each surgical tool in the image for segmentation.",
    "Please perform image segmentation on the surgical tools shown.",
    "Can you separate the surgical instruments in the image by segmenting them?",
    "Identify and segment each type of surgical instrument in the image.",
    "Segment and label all the surgical tools in this image.",
    "Could you assist by segmenting the surgical tools in this image?",
    "Perform segmentation of the surgical instruments in this picture.",
    "Can you visually segment and identify the surgical tools here?",
    "Please apply segmentation to the surgical tools in the image.",
    "Segment the different surgical instruments in the provided image.",
    "Can you delineate each surgical tool in the image clearly?",
    "Identify and segment the surgical instruments in this image, please.",
    "Please segment the surgical tools in this image clearly.",
    "Can you outline and segment the surgical instruments found in this image?",
    "Segment each surgical instrument in the image distinctly.",
    "Please show the segmentation of surgical instruments in this photo.",
    "Can you mark all the surgical tools in the image for segmentation?",
    "Please segment the surgical tools in this image for analysis.",
    "Could you identify and segment all surgical instruments in this image?",
    "Segment the visible surgical tools in the image, please.",
    "Can you segment out the surgical tools in this provided image?",
    "Please isolate and segment each surgical tool in the image.",
    "Identify, outline, and segment the surgical instruments in the image.",
    "Can you segment the various surgical instruments in this image?",
    "Please create distinct segments for each surgical tool in the image.",
    "Could you provide segmentation for each surgical tool in the image?",
    "Segment and identify all surgical tools in this image, please.",
    "Can you show the segmentation of each surgical instrument in the image?",
    "Please segment each surgical tool in the provided image.",
    "Could you outline the surgical tools in this image for segmentation?",
    "Segment the surgical instruments in the image for better visualization.",
    "Can you clearly segment each surgical tool in the image?",
    "Please provide a segmented view of the surgical tools in this image.",
    "Could you segment the surgical instruments in this photo for clarity?",
    "Segment and highlight the surgical tools in the image, please.",
    "Can you accurately segment the surgical instruments in the image?",
    "Please separate each surgical tool in the image by segmenting them.",
    "Could you isolate the surgical tools in this image through segmentation?",
    "Provide segmentation for all visible surgical tools in the image.",
    "Can you detail the segmentation of surgical instruments in the image?",
    "Please segment each individual surgical tool in the image.",
    "Could you visually separate the surgical tools in the image?",
    "Segment out each surgical tool in the image, please.",
    "Can you make clear segments for each surgical instrument in the image?",
    "Please clearly outline and segment the surgical tools in this image.",
    "Could you segment each surgical tool in this image for detailed analysis?",
    "Provide a detailed segmentation of the surgical tools in the image.",
    "Can you distinguish and segment all surgical tools in the image?",
    "Please segment and outline every surgical tool in this image.",
    "Could you create segments for each surgical tool shown in the image?",
    "Segment the surgical tools for clearer visualization in the image.",
    "Can you provide detailed segmentation of the surgical instruments?",
    "Please identify and segment the surgical tools in the image effectively.",
    "Could you highlight the segmentation of surgical tools in this image?",
    "Segment all the surgical instruments in the image thoroughly.",
    "Can you define the segments for each surgical tool in the image?",
    "Please isolate and clearly segment the surgical tools in the image.",
    "Could you ensure each surgical tool in the image is segmented?",
    "Segment each tool in the image that is used for surgery.",
    "Can you perform a detailed segmentation of the surgical tools in this picture?",
    "Please delineate and segment the surgical instruments in the image.",
    "Could you provide precise segmentation of each surgical tool?",
    "Segment the tools in the image that are used in surgical operations.",
    "Can you highlight and segment each surgical tool in the image?",
    "Please segment all tools visible in the image that are used for surgery.",
    "Could you separate and segment the surgical instruments for analysis?",
    "Segment the surgical instruments in the image, highlighting each one.",
    "Can you ensure all surgical tools in the image are segmented?",
    "Please define the segments for surgical tools in this image clearly.",
    "Could you outline and segment each tool in the image used for surgeries?",
    "Provide clear segmentation of the surgical instruments in the image.",
    "Can you segment each tool in the image that could be used in surgery?",
    "Please segment and differentiate the surgical tools in the image.",
    "Could you provide a clear segmentation for each surgical instrument?",
    "Identify and segment the tools in the image used for surgical procedures."
]

# %%
ana_detect = [
    "Can you identify the specific anatomical structures visible in the surgical image?",
    "Detect and label the sella floor in this image.",
    "Identify the tuberculum sella in the provided image.",
    "Highlight the ICA prominence on this image.",
    "Locate and label the clival recess in the image.",
    "Can you spot and identify the optic carotid recess in this image?",
    "Find the optic prominence in the image presented.",
    "Analyze the image and detect the sella floor.",
    "Identify all visible surgical anatomy structures in this image.",
    "Point out the tuberculum sella in this surgical image.",
    "Detect the ICA prominence in the image and highlight it.",
    "Is the clival recess visible in this image? Identify it.",
    "Identify and label the optic carotid recess if visible.",
    "Detect any visible optic prominence in the image.",
    "Mark the location of the sella floor in this image.",
    "Can you identify the clival recess in this surgical image?",
    "Please detect the tuberculum sella in the image.",
    "Highlight and label the ICA prominence in this image.",
    "Find and label the optic carotid recess in the image provided.",
    "Identify the optic prominence in this image.",
    "Detect all surgical anatomy structures mentioned in the image.",
    "Can you show the position of the sella floor in this image?",
    "Point out the location of the tuberculum sella in the image.",
    "Identify and highlight the ICA prominence in this image.",
    "Locate the clival recess and mark it in the image.",
    "Show where the optic carotid recess is located in the image.",
    "Label the optic prominence in this surgical image.",
    "Can you detect any anatomy structures like the sella floor in this image?",
    "Highlight the tuberculum sella in this image.",
    "Mark and identify the ICA prominence visible in the image.",
    "Is the clival recess identifiable in this image? Highlight it.",
    "Detect the optic carotid recess and label it.",
    "Point out and label the optic prominence in this image.",
    "Can you find the sella floor in this image? Mark it.",
    "Identify the tuberculum sella in the image provided.",
    "Highlight the presence of the ICA prominence in this image.",
    "Can you locate the clival recess in this image?",
    "Detect and mark the optic carotid recess in the image.",
    "Identify and highlight the optic prominence in this image.",
    "Examine the image for the sella floor and identify it.",
    "Can you locate and label the tuberculum sella in the image?",
    "Is there an ICA prominence visible? Please identify it.",
    "Find the clival recess in the image and mark it.",
    "Label any visible optic carotid recess in the image.",
    "Can you detect and label the optic prominence in this image?",
    "Identify all detailed structures like sella floor in this image.",
    "Highlight the location of the tuberculum sella in the image.",
    "Label the ICA prominence clearly in the image.",
    "Detect the clival recess and provide its location in the image.",
    "Can the optic carotid recess be identified in this image?",
    "Locate and highlight the optic prominence in the provided image.",
    "Carefully analyze and detect the sella floor in this image.",
    "Point out the tuberculum sella in this surgical image.",
    "Highlight and label all instances of ICA prominence in the image.",
    "Can you identify the location of the clival recess in this image?",
    "Detect and label the optic carotid recess if present in the image.",
    "Mark the optic prominence in the image and confirm its location.",
    "Detect all mentioned anatomical structures like the sella floor in this image.",
    "Can you find and highlight the tuberculum sella here?",
    "Identify the ICA prominence in this image, marking its location.",
    "Show me the clival recess in this surgical image.",
    "Find and label the optic carotid recess in the provided image.",
    "Can you locate the optic prominence in this image and mark it?",
    "Locate the sella floor in this image and identify it.",
    "Highlight the tuberculum sella and provide details in the image.",
    "Mark the ICA prominence clearly on the image.",
    "Identify the clival recess in this image.",
    "Can you locate and identify the optic carotid recess in this image?",
    "Detect the optic prominence and label its position.",
    "Examine the image and find the sella floor.",
    "Point to the tuberculum sella and identify it in this image.",
    "Highlight the ICA prominence and its relevance in the image.",
    "Can you spot the clival recess? Mark its position.",
    "Identify the optic carotid recess in this image and highlight it.",
    "Mark and identify the optic prominence in the image provided.",
    "Detect and label the detailed anatomy structures like the sella floor.",
    "Can you identify the tuberculum sella in this image?",
    "Find and highlight the ICA prominence in this image.",
    "Mark the location of the clival recess in this image.",
    "Detect if there is an optic carotid recess visible in the image.",
    "Identify and mark the optic prominence in this image.",
    "Can you detect the sella floor in this image?",
    "Highlight the tuberculum sella and its details in the image.",
    "Locate and label the ICA prominence in this image.",
    "Find the clival recess and mark it clearly.",
    "Can the optic carotid recess be identified and labeled in this image?",
    "Locate and mark the optic prominence in the image provided.",
    "Point out any visible structures like the sella floor in this image.",
    "Highlight and label the tuberculum sella in this image.",
    "Detect the ICA prominence and provide its exact location in the image.",
    "Is the clival recess visible? Identify and mark it.",
    "Identify any optic carotid recess in this image and highlight it.",
    "Can you find the optic prominence? Mark its location.",
    "Locate all the anatomical structures mentioned, like the sella floor, in the image."
]

# %%
ana_seg = [
    "Can you segment the specific anatomical structures visible in the surgical image?",
    "Please identify and segment the Sella floor in this image.",
    "Could you outline the Tuberculum sella in the displayed surgical image?",
    "Segment the ICA prominence from the rest of the surgical anatomy.",
    "Highlight the Clival recess in the image provided.",
    "Identify and segment the Optic carotid recess in this surgical image.",
    "Can you isolate and segment the Optic prominence in the image?",
    "Please delineate each anatomical structure in the surgical image.",
    "Can the AI segment the Sella floor distinctly in this image?",
    "Could you provide a segmented visualization of the Tuberculum sella?",
    "Isolate the ICA prominence using your segmentation tools.",
    "Perform segmentation on the Clival recess shown in the image.",
    "Please segment the Optic carotid recess with precision.",
    "Can you accurately segment the Optic prominence in this image?",
    "Use your segmentation skills to distinguish the Sella floor.",
    "Highlight and segment the Tuberculum sella area.",
    "Identify and isolate the ICA prominence through segmentation.",
    "Segment and outline the Clival recess clearly.",
    "Focus on the Optic carotid recess and segment it.",
    "Delineate the Optic prominence in this surgical picture.",
    "Segment each of these structures: Sella floor, Tuberculum sella, and Clival recess.",
    "Can you segment the ICA prominence and Optic prominence separately?",
    "Provide a clear segmentation of the Tuberculum sella and Optic carotid recess.",
    "Segment the Sella floor with high precision.",
    "Could you segment these structures for a clearer surgical view?",
    "Highlight the Tuberculum sella in the image with a segmentation overlay.",
    "Please segment the ICA prominence for detailed analysis.",
    "Can you segment and label the Clival recess in this image?",
    "Identify and segment the Optic carotid recess for educational purposes.",
    "Segment the Optic prominence to assist in surgical planning.",
    "Please isolate the Sella floor and provide a segmented outline.",
    "Can you enhance the Tuberculum sella by segmenting it?",
    "Segment the ICA prominence to differentiate it from adjacent structures.",
    "Provide a segmented view of the Clival recess.",
    "Can you perform a detailed segmentation on the Optic carotid recess?",
    "Outline and segment the Optic prominence for better visualization.",
    "Segment the Sella floor to aid in medical training.",
    "Please provide segmentation of the Tuberculum sella for research purposes.",
    "Can you segment the ICA prominence clearly in this complex image?",
    "Segment the Clival recess to help understand its boundaries.",
    "Please segment the Optic carotid recess distinctly.",
    "Can you provide a segmented map of the Optic prominence?",
    "Segment and enhance the Sella floor for a surgical review.",
    "Focus on segmenting the Tuberculum sella to assist surgeons.",
    "Can you isolate the ICA prominence for a clinical study?",
    "Segment the Clival recess to explore its anatomical details.",
    "Can you clearly segment the Optic carotid recess for a presentation?",
    "Segment the Optic prominence for a detailed anatomical study.",
    "Can you perform segmentation on all visible structures in this surgical area?",
    "Please segment the Sella floor to clarify its boundaries.",
    "Can you delineate the Tuberculum sella for educational purposes?",
    "Segment the ICA prominence to provide clarity in this image.",
    "Can you outline the Clival recess with segmentation techniques?",
    "Segment the Optic carotid recess for better surgical navigation.",
    "Please provide a detailed segmentation of the Optic prominence.",
    "Segment the Sella floor to assist in medical diagnosis.",
    "Can you clearly segment and label the Tuberculum sella?",
    "Isolate and segment the ICA prominence for further analysis.",
    "Please segment the Clival recess to assist in surgical preparation.",
    "Can you provide detailed segmentation of the Optic carotid recess?",
    "Segment the Optic prominence to facilitate accurate surgery planning.",
    "Please segment the Sella floor and provide an analysis of the area.",
    "Can you segment the Tuberculum sella for a clearer view during surgery?",
    "Please segment the ICA prominence to distinguish it from surrounding tissues.",
    "Can you provide a segmented view of the Clival recess?",
    "Segment the Optic carotid recess to help with surgical approaches.",
    "Can you outline and segment the Optic prominence for clinical reference?",
    "Highlight and segment the Sella floor to assist in educational demonstrations.",
    "Please segment the Tuberculum sella for better anatomical understanding.",
    "Segment the ICA prominence to help differentiate it in medical imaging.",
    "Can you provide a clear segmentation of the Clival recess?",
    "Segment and label the Optic carotid recess in this image.",
    "Can you focus on segmenting the Optic prominence?",
    "Please provide a segmented outline of the Sella floor for surgical reference.",
    "Segment the Tuberculum sella to aid in medical procedures.",
    "Can you clearly segment the ICA prominence for a medical study?",
    "Segment the Clival recess to provide insights into its anatomical features.",
    "Can you segment the Optic carotid recess and provide its dimensions?",
    "Please segment and highlight the Optic prominence for surgical analysis.",
    "Can you segment all the mentioned anatomical structures for a comprehensive study?",
    "Segment the Sella floor to provide a detailed view for surgeons.",
    "Please isolate and segment the Tuberculum sella for precise medical illustration.",
    "Can you provide a segmentation of the ICA prominence for detailed examination?",
    "Segment the Clival recess to facilitate educational discussions.",
    "Can you segment the Optic carotid recess for better clarity in medical imaging?",
    "Please provide a segmented view of the Optic prominence for a surgical guide.",
    "Can you segment and label each key anatomical structure in the surgical image?",
    "Segment the Sella floor to enhance visibility during surgical procedures.",
    "Can you provide precise segmentation of the Tuberculum sella for clinical analysis?",
    "Segment the ICA prominence to help in identifying its exact location.",
    "Can you segment the Clival recess for better visualization in surgical planning?",
    "Please segment the Optic carotid recess to assist in anatomical studies.",
    "Segment the Optic prominence with precision to aid in surgical interventions."
]

# %%
skill = [
    "How proficient is the surgeon in performing the surgery based on the endoscopic image?",
    "Can you give me a score of skill based on this image?",
    "Rate the surgical technique shown in this image.",
    "Evaluate the surgeon's skill level from this surgical photo.",
    "Provide a proficiency score for the surgical procedure in this image.",
    "Assess the quality of surgery in this image.",
    "Can this image be used to determine the surgeon's skill?",
    "Grade the surgical skill demonstrated in this image.",
    "How well did the surgeon perform in this image?",
    "Is the technique in this image up to professional standards?",
    "Score the execution of the surgery shown in this image.",
    "How adept is the surgeon based on the technique shown in this image?",
    "From this image, rate the surgeon's proficiency.",
    "Can you determine the skill level from this surgical image?",
    "Give a performance score for the surgery in this picture.",
    "What is the skill level of the surgeon in this image?",
    "Analyze and score the surgical technique in this image.",
    "Is the surgery in this image performed perfectly?",
    "Judge the surgical skills shown in this image.",
    "How accurately is the procedure performed in this image?",
    "Assess the surgeon's performance based on this image.",
    "Provide a detailed skill score from this surgical image.",
    "Does this image reflect high surgical skill?",
    "Evaluate the precision of the surgical technique in the image.",
    "Can you score the surgical accuracy from this image?",
    "Determine the proficiency demonstrated in this surgical image.",
    "How effective is the surgical method in this image?",
    "Rate the surgeon's skill as seen in this image.",
    "How competent is the surgeon from this image assessment?",
    "Can you provide a skill assessment for the surgery in this image?",
    "Score the level of skill displayed in this surgical image.",
    "Is the surgical technique in this image of high quality?",
    "How capable is the surgeon according to this image?",
    "Analyze the surgical skill level in this image.",
    "Evaluate how well the surgery is performed in this image.",
    "Score the surgeon's performance based on this image.",
    "Provide a skill rating for the surgeon in this image.",
    "Is this surgery performed to a high standard in this image?",
    "Judge the level of surgical expertise shown in this image.",
    "How well does this image demonstrate surgical skill?",
    "Rate the effectiveness of the surgical technique in this image.",
    "Does the image show a perfect surgical performance?",
    "Assess the skill level shown in this surgical image.",
    "Grade the proficiency of the surgery in this image.",
    "Can you evaluate the surgeon’s technique from this image?",
    "Provide a rating based on the surgical skills in this image.",
    "How proficiently is the surgical procedure executed in this image?",
    "Determine the level of surgical expertise from this image.",
    "What skill score would you give based on this surgical image?",
    "Is the surgery in this image performed expertly?",
    "Analyze and provide feedback on the surgical skill in this image.",
    "Can you assess the surgical precision in this image?",
    "Provide a competence score for this surgical performance.",
    "How effectively is the surgery carried out in this image?",
    "Evaluate the surgical skills based on this endoscopic image.",
    "Rate the surgeon's handling of the procedure in this image.",
    "Grade the surgery based on the skills shown in this image.",
    "How well is the surgical technique applied in this image?",
    "Can the surgeon’s skill be quantified from this image?",
    "Provide an expert score for the surgery performed in this image.",
    "Judge the craftsmanship of the surgery in this image.",
    "How meticulous is the surgery in this image?",
    "Assess the execution quality of the surgical procedure in this image.",
    "Can you score the surgical method shown in this image?",
    "Evaluate the surgeon's technical skill from this image.",
    "Rate the precision of the surgeon in this surgical image.",
    "Is the surgical work in this image flawless?",
    "Provide a score reflecting the surgical skill level in this image.",
    "How professional is the surgery conducted in this image?",
    "Analyze the surgeon's technique based on this image.",
    "Can you provide a qualitative skill assessment of this image?",
    "Determine the skill rating from the surgical technique in this image.",
    "How proficient is the surgical execution in this image?",
    "Evaluate the surgeon's ability based on this surgical image.",
    "Can the image illustrate the surgeon's proficiency?",
    "Rate the surgical outcome shown in this image.",
    "Judge the effectiveness of the surgical maneuvers in this image.",
    "How skilled is the surgeon as depicted in this image?",
    "Assess the surgeon's skill from the procedural accuracy in this image.",
    "Provide a performance evaluation based on the surgical image.",
    "Is the surgical technique in this image executed proficiently?",
    "Evaluate the surgeon's skill from the procedural detail in this image.",
    "Rate the surgical performance as shown in this image.",
    "How capable is the surgeon based on the execution in this image?",
    "Can you give a detailed analysis of the surgical skill from this image?",
    "Judge the precision of the surgery in this image.",
    "Provide an assessment of the surgical technique in this image.",
    "How does the surgical technique in this image rate on a scale of perfection?",
    "Is the surgical practice in this image of an expert level?",
    "Assess the surgeon's proficiency from the technique shown in this image.",
    "Provide a critical evaluation of the surgery in this image.",
    "Can you determine the surgeon's skill level from how the surgery is performed in this image?"
]

# %%
with open("/mnt/xingjian_luo/dataset/surgFC/dataset/triplet/triplet_tool_614.json","r") as f:
    triplet_sample = json.load(f)

questions = [i["conversations"][0]["value"] for i in triplet_sample]

# %%
triplet = np.random.choice(questions,90).tolist()

# %%
depth  = [
    "Can you generate a depth map for this surgical image?",
    "What depth information can be gathered from this image?",
    "Please estimate the depth at various points in this surgical image.",
    "Could you analyze the depth profile of this surgical photograph?",
    "Extract depth map data from this image, please.",
    "Can you determine the depth variations in this surgical image?",
    "Generate a detailed depth map from this photograph.",
    "How deep are the structures visible in this image?",
    "Can you compute the depth field for this surgery-related image?",
    "Provide a visualization of depth in this surgical photo.",
    "Create a depth contour map of this image.",
    "Can you elaborate on the depth features of this image?",
    "What are the depth levels in this surgical image?",
    "Estimate the relative depths in this photograph.",
    "Generate a 3D depth map from this 2D surgical image.",
    "Please map out depths in this surgical scene.",
    "Can you visualize depth distribution in this image?",
    "How can we interpret the depth data from this surgical image?",
    "Provide a depth analysis of the visible organs in this image.",
    "Can you show depth variations across this surgical field?",
    "Display the depth information overlay for this image.",
    "Create a depth heatmap for this surgical photograph.",
    "Can you identify the deepest part of this image?",
    "What is the depth range in this surgical image?",
    "Please convert this surgical image into a depth map.",
    "Can you point out the shallow and deep areas in this image?",
    "Generate a depth profile across the center of this image.",
    "How consistent is the depth in this surgical image?",
    "Can you render a depth gradient map for this photograph?",
    "Analyze the depth to help understand surgical complexities.",
    "Can you quantify depth in millimeters for this surgical image?",
    "Provide a depth calculation for each layer visible in this image.",
    "What is the minimum and maximum depth in this image?",
    "Can you overlay depth cues on this surgical image?",
    "Generate a report on the depth characteristics of this image.",
    "Can you provide a detailed depth analysis for this surgical procedure?",
    "Estimate depth based on the shadows in this image.",
    "Can you assess the depth accuracy in this surgical image?",
    "Generate a depth map highlighting critical areas in this image.",
    "Can you compare depth between two areas in this surgical image?",
    "Provide a segmented depth map based on different tissues shown.",
    "Can you analyze depth for pre-surgical planning using this image?",
    "What does the depth tell us about the surgical site in this image?",
    "Can you map out depth from the surface to the deepest point?",
    "Generate a depth histogram for this surgical image.",
    "Can you provide depth details for the organs in this image?",
    "Estimate the depth for surgical navigation purposes.",
    "Can you simulate depth perception for this surgical image?",
    "Provide a detailed depth field analysis for surgical assessment.",
    "Generate a depth map using artificial intelligence techniques.",
    "Can you calculate the depth using image processing algorithms?",
    "What depth information can you extract from different colors in this image?",
    "Provide a depth map to assist in robotic surgery.",
    "Can you determine depth relevance for surgical interventions?",
    "Generate a depth field to evaluate surgical risks.",
    "Can you analyze the depth for different surgical tools visible in this image?",
    "Provide a depth comparison across this surgical site.",
    "Can you use depth estimation to assess surgery complexity?",
    "Generate a depth map to guide surgical incisions.",
    "How can depth perception assist in minimizing surgical errors?",
    "Provide a depth map to help differentiate tissue types.",
    "Can you estimate the depth for each surgical layer captured in this image?",
    "Generate a virtual depth model for this surgical scenario.",
    "Can you provide a depth map for planning surgical routes?",
    "What are the implications of depth findings in this surgical image?",
    "Can you analyze the depth to enhance surgical precision?",
    "Provide depth-based insights for surgical education.",
    "How does depth variation affect the surgical outcome in this image?",
    "Can you provide a depth map for real-time surgical guidance?",
    "Generate a depth analysis to support surgical decision-making.",
    "Can you simulate different depth levels in this surgical image?",
    "Provide a depth map to identify critical structures in surgery.",
    "Can you detail the depth for enhanced surgical visualization?",
    "Estimate depth to help in the placement of surgical instruments.",
    "Can you provide depth information to avoid critical areas during surgery?",
    "Generate a depth map to understand tissue layering in surgery.",
    "How can depth estimation improve surgical safety?",
    "Can you provide a depth guide for minimally invasive surgery?",
    "Generate a depth map that highlights potential surgical hazards.",
    "Can you measure the depth of specific features in this surgical image?",
    "Provide a depth analysis for surgical training purposes.",
    "Can you evaluate depth perception in a simulated surgical environment?",
    "Generate a depth map to analyze surgical approaches.",
    "Can you provide depth cues for navigating complex surgical areas?",
    "Estimate the depth to optimize surgical outcomes.",
    "Can you provide a depth map as a reference for surgical preparation?",
    "Generate a depth field to facilitate surgical tool navigation.",
    "Can you provide depth insights for advanced surgical procedures?",
    "Generate a depth map to assist in surgical analysis and review."
]

# %%
reconstruct = [
    "Can you reconstruct this image to remove the tools?",
    "Can you provide a clear image free from any surgical equipment?",
    "Please edit out the surgical tools from this image.",
    "Could you remove all instruments from this surgical image?",
    "Generate a version of this photo without the surgical tools.",
    "Can you clear the surgical tools from this image?",
    "Please provide an image reconstruction with no tools visible.",
    "Could you produce an image of the surgery without any tools?",
    "Edit this image to eliminate all visible surgical instruments.",
    "Remove all medical instruments from this image, please.",
    "Can you retouch this image to exclude the surgical tools?",
    "Provide a clean version of this image without the instruments.",
    "Can you modify this surgical image to remove the tools?",
    "Please clean up this image by removing all surgical equipment.",
    "Produce an image of the surgery area with no tools in sight.",
    "Can you digitally remove the tools from this surgical photo?",
    "Please erase the surgical instruments from this image.",
    "Could you clear out the instruments from this picture?",
    "Create a tool-free version of this surgical image.",
    "Edit out the instruments from this surgical scene, please.",
    "Can you make this image look like there were no tools used?",
    "Provide an image of the surgical area devoid of any equipment.",
    "Could you retouch this image to remove the surgical tools?",
    "Make this surgical image clean by removing all tools.",
    "Can you strip this image of all surgical instruments?",
    "Please provide a version of this image without surgical tools.",
    "Can you deliver a version of this image that's tool-free?",
    "Please reconstruct this image to appear without any instruments.",
    "Remove the surgical tools from this image for a clearer view.",
    "Edit this image to show no signs of surgical equipment.",
    "Can you process this image to exclude all tools?",
    "Please deliver a surgical image without any tools.",
    "Could you edit out every tool from this surgical image?",
    "Create a surgical image that appears tool-less.",
    "Please ensure this image contains no surgical tools.",
    "Can you edit this surgical photo to remove all tools?",
    "Provide a clearer version of this image with no instruments.",
    "Can you make this image appear as if surgery was done without tools?",
    "Please remove all visible tools from this surgical image.",
    "Edit the surgical tools out of this image.",
    "Can you reconstruct this image to show a clean surgery area?",
    "Please make this surgical scene free from any instruments.",
    "Could you digitally clean this image by removing the tools?",
    "Generate a clean surgical area in this image without equipment.",
    "Can you modify this image to have no visible surgical tools?",
    "Please provide an image that shows the surgery without tools.",
    "Remove all tools from this image to show just the surgery.",
    "Can you edit this image to exclude surgical instruments?",
    "Please make this image tool-free.",
    "Create an image that has no surgical tools visible.",
    "Can you clear the surgical area in this image of all tools?",
    "Please retouch this image to remove any surgical instruments.",
    "Could you provide an image of this area without surgical tools?",
    "Edit this image to make it free from surgical equipment.",
    "Can you remove the tools for a clearer surgical image?",
    "Please clean this image of all surgical tools.",
    "Generate an image without the surgical tools shown.",
    "Can you reconstruct this image without the surgical equipment?",
    "Please provide a tool-free surgical image.",
    "Could you edit this image to remove all signs of surgery tools?",
    "Create a version of this image that has no tools.",
    "Can you produce a clean image of the surgery without equipment?",
    "Please edit this surgical image to have no tools visible.",
    "Can you remove all surgical tools from this image?",
    "Provide an image with the surgery scene but without tools.",
    "Could you clear this image from any surgical instruments?",
    "Edit the tools out of this image, please.",
    "Can you provide an image of just the surgical site without tools?",
    "Please reconstruct this image to have no surgery tools.",
    "Remove any visible surgical equipment from this image.",
    "Can you clean up the image by removing surgical tools?",
    "Please provide an image without any surgical tools or equipment.",
    "Could you remove the instruments from this image for a clearer view?",
    "Edit this image to be free of any surgical tools.",
    "Can you make this surgical image look like no tools were used?",
    "Please provide a version of this image that has no surgical instruments.",
    "Can you deliver a clear image by removing the tools?",
    "Please edit out the surgical tools from this image for clarity.",
    "Could you reconstruct this image without any tools showing?",
    "Create a clean version of this surgical scene without instruments.",
    "Can you eliminate the surgical tools from this image?",
    "Please provide an image with no tools involved in the surgery.",
    "Could you make this image of the surgery look tool-free?",
    "Edit out all surgical instruments from this image.",
    "Can you provide a clear image of the surgery without tools?",
    "Please remove all the tools from this surgical image."
]

# %%
print(len(tool_detect))
print(len(tool_seg))
print(len(ana_detect))
print(len(ana_seg))
print(len(skill))
print(len(triplet))
print(len(depth))
print(len(reconstruct))
# Out:
# 90
# 90
# 94
# 93
# 92
# 90
# 89
# 86

# %%
dataset_dict = {
    "tool_detect_model":tool_detect,
    "tool_segment_model":tool_seg,
    "anatomy_detect_model":ana_detect,
    "anatomy_segment_model":ana_seg,
    "skill_model":skill,
    "triplet_model":triplet,
    "depth_model":depth,
    "reconstruct_model":reconstruct
}

# %%
test_list = []
for i,v in dataset_dict.items():
    
    for item in v:
        temp_dict = {}
        temp_dict["question"] = item
        temp_dict["gt_model"] = i
        test_list.append(temp_dict)

# %%
with open("surgFC_test.json","w") as f:
    f.write(json.dumps(test_list,indent=2))
